# %% [markdown]
# # 4 - 1

# %%
import seaborn as sns
anscombe = sns.load_dataset('anscombe')
print(anscombe)
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %% [markdown]
# # 4 - 2

# %%
import matplotlib.pyplot as plt

# %%
dataset_1 = anscombe[anscombe['dataset'] == 'I']
plt.plot(dataset_1['x'], dataset_1['y'])
plt.show()

# %%
plt.plot(dataset_1['x'], dataset_1['y'], 'o')
plt.show()

# %%
dataset_2 = anscombe[anscombe['dataset'] == 'II']
dataset_3 = anscombe[anscombe['dataset'] == 'III']
dataset_4 = anscombe[anscombe['dataset'] == 'IV']

# %%
fig = plt.figure()
axes1 = fig.add_subplot(2, 2, 1)
axes2 = fig.add_subplot(2, 2, 2)
axes3 = fig.add_subplot(2, 2, 3)
axes4 = fig.add_subplot(2, 2, 4)
plt.show()

# %%
fig = plt.figure()
axes1 = fig.add_subplot(2, 2, 1)
axes2 = fig.add_subplot(2, 2, 2)
axes3 = fig.add_subplot(2, 2, 3)
axes4 = fig.add_subplot(2, 2, 4)

axes1.plot(dataset_1['x'], dataset_1['y'], 'o')
axes2.plot(dataset_2['x'], dataset_2['y'], 'o')
axes3.plot(dataset_3['x'], dataset_3['y'], 'o')
axes4.plot(dataset_4['x'], dataset_4['y'], 'o')

plt.show()

# %%
fig = plt.figure()
axes1 = fig.add_subplot(2, 2, 1)
axes2 = fig.add_subplot(2, 2, 2)
axes3 = fig.add_subplot(2, 2, 3)
axes4 = fig.add_subplot(2, 2, 4)

axes1.plot(dataset_1['x'], dataset_1['y'], 'o')
axes2.plot(dataset_2['x'], dataset_2['y'], 'o')
axes3.plot(dataset_3['x'], dataset_3['y'], 'o')
axes4.plot(dataset_4['x'], dataset_4['y'], 'o')

axes1.set_title('dataset_1')
axes2.set_title('dataset_2')
axes3.set_title('dataset_3')
axes4.set_title('dataset_4')

fig.suptitle('Anscombe Data')
fig.set_tight_layout(True)

plt.show()

# %%
# fig.set_tight_layout의 ()안에 False를 넣으면 어떻게 될까?
# fig = plt.figure()
# axes1 = fig.add_subplot(2, 2, 1)
# axes2 = fig.add_subplot(2, 2, 2)
# axes3 = fig.add_subplot(2, 2, 3)
# axes4 = fig.add_subplot(2, 2, 4)

# axes1.plot(dataset_1['x'], dataset_1['y'], 'o')
# axes2.plot(dataset_2['x'], dataset_2['y'], 'o')
# axes3.plot(dataset_3['x'], dataset_3['y'], 'o')
# axes4.plot(dataset_4['x'], dataset_4['y'], 'o')

# axes1.set_title('dataset_1')
# axes2.set_title('dataset_2')
# axes3.set_title('dataset_3')
# axes4.set_title('dataset_4')

# fig.suptitle('Anscombe Data')
# fig.set_tight_layout(False)

# plt.show()
# 결과 : 이름이 겹쳐져서 잘 안보인다.

# %%
# fig.set_tight_layout(True)를 안쓰면 어떻게 될까?
# fig = plt.figure()
# axes1 = fig.add_subplot(2, 2, 1)
# axes2 = fig.add_subplot(2, 2, 2)
# axes3 = fig.add_subplot(2, 2, 3)
# axes4 = fig.add_subplot(2, 2, 4)

# axes1.plot(dataset_1['x'], dataset_1['y'], 'o')
# axes2.plot(dataset_2['x'], dataset_2['y'], 'o')
# axes3.plot(dataset_3['x'], dataset_3['y'], 'o')
# axes4.plot(dataset_4['x'], dataset_4['y'], 'o')

# axes1.set_title('dataset_1')
# axes2.set_title('dataset_2')
# axes3.set_title('dataset_3')
# axes4.set_title('dataset_4')

# fig.suptitle('Anscombe Data')

# plt.show()
# 결과 : 이름이 겹쳐져서 잘 안보인다.

# %% [markdown]
# # 4 - 3

# %%
tips = sns.load_dataset('tips')
print(tips)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
fig = plt.figure()

axes1 = fig.add_subplot(1, 1, 1)

# %%
axes1.hist(data=tips, x='total_bill', bins=10)

axes1.set_title('Histogram of Total Bill')  
axes1.set_xlabel('Total Bill')  
axes1.set_ylabel('Frequency')  

plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # 문제 발생 및 해결

# %% [markdown]
# ### p125 코드 작성 했으나 출력이 안되는 문제 발생

# %% [markdown]
# ```
# axes1.hist(data=tips, x='total_bill', bins=10)
#
# axes1.set_title('Histogram of Total Bill')
# axes1.set_xlabel('Total Bill')
# axes1.set_ylabel('Frequency')
#
# plt.show()
# ```

# %% [markdown]
# ###  p125 코드 작성 했으나 출력이 안되는 문제 해결

# %% [markdown]
# >* p126을 보고 해결함.
# >* 나는 그림 영역 객체 fig 코드와 히스토그램을 작성하는 코드를 각각 다른 행에 작성해서 실행이 되지 않음.
# 아래와 같이 같은 행에 작성해야 그림 영역 객체 안에 그래프가 그려짐.
#
# ###### 문제 해결 코드
# ```
# fig = plt.figure()
#
# axes1 = fig.add_subplot(1, 1, 1)
#
# axes1.hist(data=tips, x='total_bill', bins=10)
#
# axes1.set_title('Histogram of Total Bill')
# axes1.set_xlabel('Total Bill')
# axes1.set_ylabel('Frequency')
#
# plt.show()
# ```

# %% [markdown]
# ###  p125 코드 작성 했으나 출력이 안되는 문제 해결 결과

# %%
fig = plt.figure()

axes1 = fig.add_subplot(1, 1, 1)

axes1.hist(data=tips, x='total_bill', bins=10)

axes1.set_title('Histogram of Total Bill')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Frequency')

plt.show()

# %% [markdown]
# ## 해결 완료

# %% [markdown]
# ### 마크다운 사용법 참고
# - [주피터 노트북 마크다운 기능 정리 블로그](https://leedakyeong.tistory.com/entry/Markdown-Jupyter-Notebook-%EC%A3%BC%ED%94%BC%ED%84%B0-%EB%85%B8%ED%8A%B8%EB%B6%81-%EB%A7%88%ED%81%AC%EB%8B%A4%EC%9A%B4-%EC%A0%95%EB%A6%AC)
# - [주피터 노트북 링크 저장 기능 안내 블로그](https://m.blog.naver.com/iklues_/221613873389)
# - [주피터 노트북 마크다운 코드 입력 안내 블로그](https://lucy-the-marketer.kr/ko/growth/python-jupyter-notebook-guidebook-for-newbies/)

# %% [markdown]
# ---

# %%
scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(1, 1, 1)

axes1.scatter(tips['total_bill'], tips['tip'])

axes1.set_title('Scatterplot of Total Bill vs Tip')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip')

plt.show()

# %%
boxplot = plt.figure()
axes1 = boxplot.add_subplot(1, 1, 1)

axes1.boxplot(
    x = [
        tips[tips['sex'] == 'Female']['tip'],
        tips[tips['sex'] == 'Male']['tip']
    ],
    labels = ['Female', 'Male']
)

axes1.set_xlabel('Sex')
axes1.set_ylabel('Tip')
axes1.set_title('Boxplot of Tips by Sex')

plt.show()

# %%
colors = {'Female' : '#f1a340', 'Male' : '#998ec3'}

scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(1, 1, 1)

axes1.scatter(data = tips,
             x = 'total_bill',
             y = 'tip',
             s = tips['size'] ** 2 * 10,
             c = tips['sex'].map(colors),
             alpha = 0.5)

axes1.set_title('Colored by Sex and Sized by Size')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip')

scatter_plot.suptitle('Total Bill vs Tip')

plt.show()

# %% [markdown]
# # 4 - 4

# %%
import seaborn as sns

tips = sns.load_dataset('tips')

# %%
sns.set_context('paper')

# %%
hist, ax = plt.subplots()

sns.histplot(data = tips, x = 'total_bill', ax = ax)
ax.set_title('Total Bill Histogram')

plt.show()

# %%
den, ax = plt.subplots()

sns.kdeplot(data = tips, x = 'total_bill', ax = ax)

ax.set_title('Total Bill Density')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Unit Probability')

plt.show()

# %%
rug, ax = plt.subplots()

sns.rugplot(data = tips, x = 'total_bill', ax = ax)
sns.histplot(data = tips, x = 'total_bill', ax = ax)

ax.set_title('Rug Plot and Histogram of Total Bill')

plt.show()

# %%
fig = sns.displot(data = tips, x = 'total_bill', kde = True, rug = True)

fig.set_axis_labels(x_var = 'Total Bill', y_var = 'Count')
fig.figure.suptitle('Distribution of Total Bill')

plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # 문제 발생 및 해결2

# %% [markdown]
# ### p134 코드 실행 중 빨간 문구 뜸. 뭘까
# > C:\Users\hpky0\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
#   >> 해석?
# UserWarning: The figure layout has changed to tight self. / 사용자 경고 : 피규어 레이아웃이 타이트하게 변경되었습니다.
# self._figure. / 이건 뭘까?
# tight_layout(*args, **kwargs) / 이건 뭘까?22

# %% [markdown]
# ### 빨간 문구가 경고 문구임을 알게됨.
# ### 구글에 검색해서 함수를 알아봄.
# > * [tight_layout()](https://kongdols-room.tistory.com/98)

# %%
# 함수를 사용해 경고 문구가 없어지는 지 확인
fig = sns.displot(data = tips, x = 'total_bill', kde = True, rug = True)

fig.set_axis_labels(x_var = 'Total Bill', y_var = 'Count')
fig.figure.suptitle('Distribution of Total Bill')

plt.tight_layout()

plt.show()

# %% [markdown]
# ### 구글에 검색하니 matplotlib 버전이 낮아서 나오는 경고 문구라고 함.
# > * 오류 문구 [conda install matplotlib[version='>=3.7.3']](https://stackoverflow.com/questions/76901874/userwarning-the-figure-layout-has-changed-to-tight-self-figure-tight-layouta)

# %% [markdown]
# ### 라이브러리 버전을 확인 후 업그레이드해서 경고 문구를 없애고자함.
# > * [라이브러리 모듈 버전 확인하는 법 안내 블로그](https://lungfish.tistory.com/entry/python-%ED%8C%8C%EC%9D%B4%EC%8D%AC-%EB%9D%BC%EC%9D%B4%EB%B8%8C%EB%9F%AC%EB%A6%AC-%EB%AA%A8%EB%93%88-%EB%B2%84%EC%A0%84-%ED%99%95%EC%9D%B8%ED%95%98%EA%B8%B0)
# > * [라이브러리 업그레이드 하는 법 안내 블로그](https://cucucacadev.tistory.com/3)
# > * [라이브러리 업그레이드 중 오류 발생으로 해결 방법 추가로 알아본 블로그](https://log-laboratory.tistory.com/329)

# %%
# 사용 라이브러리 버전 확인
# !pip list
# Out:
# Package                       Version
# ----------------------------- ---------------
# aiobotocore                   2.5.0
# aiofiles                      22.1.0
# aiohttp                       3.8.5
# aioitertools                  0.7.1
# aiosignal                     1.2.0
# aiosqlite                     0.18.0
# alabaster                     0.7.12
# anaconda-anon-usage           0.4.2
# anaconda-catalogs             0.2.0
# anaconda-client               1.12.1
# anaconda-cloud-auth           0.1.3
# anaconda-navigator            2.5.0
# anaconda-project              0.11.1
# anyio                         3.5.0
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.3
# astroid                       2.14.2
# astropy                       5.1
# asttokens                     2.0.5
# async-timeout                 4.0.2
# atomicwrites                  1.4.0
# ...

# %%
# 라이브러리 업그레이드 
# !pip install --user --upgrade matplotlib

# %%
# 업그레이드 후 경고 문구가 발생하는 지 확인
fig = sns.displot(data = tips, x = 'total_bill', kde = True, rug = True)

fig.set_axis_labels(x_var = 'Total Bill', y_var = 'Count')
fig.figure.suptitle('Distribution of Total Bill')

plt.show()

# %% [markdown]
# ### 업그레이드 후에도 경고 문구가 떠서 추가로 알아보니 2023. 12. 2.부터 matplotlib과 seaborn에서 발생한 오류임을 알 수 있었음.
# > * [경고 문구에 대한 안내가 적혀있는 github](https://github.com/mwaskom/seaborn/issues/3431)

# %% [markdown]
# ### 해결을 위해서는 matplotlib 다운 그레이드 혹은 새로 버전이 나오면 업데이트하는 방법 외에는 없음.

# %% [markdown]
# ### 파일 저장 후 껐다가 다시 켜서 재실행하니 경고 문구가 없어짐.
# ## 해결 완료

# %% [markdown]
# ---

# %%
count, ax = plt.subplots()

sns.countplot(data = tips, x = 'day', palette = 'viridis', ax = ax)

ax.set_title('Count of days')
ax.set_xlabel('Day of the Week')
ax.set_ylabel('Frequency')

plt.show()
# Out:
# C:\Users\hpky0\AppData\Local\Temp\ipykernel_26580\640177428.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data = tips, x = 'day', palette = 'viridis', ax = ax)

# %% [markdown]
# ---

# %% [markdown]
# # 문제 발생 및 해결3

# %% [markdown]
# ### p135 코드 실행 중 경고 문구가 뜸.
# ### 경고 문구를 해석함.
# > `hue`를 할당하지 않고 `palette`를 전달하는 것은 더 이상 사용되지 않으며 v0.14.0에서 제거될 예정입니다. 동일한 효과를 얻으려면 `x` 변수를 `hue`에 할당하고 `legend=False`를 설정하세요.
# ### 경고 문구의 말대로 `legend = False`를 추가해 아래와 같이 코드를 작성해봄.
# ```
# count, ax = plt.subplots()
#
# sns.countplot(data = tips, x = 'day', palette = 'viridis', legend=False, ax = ax)
#
# ax.set_title('Count of days')
# ax.set_xlabel('Day of the Week')
# ax.set_ylabel('Frequency')
#
# plt.show()
# ```

# %%
# 함수 추가 후 경고 문구가 발생하는 지 확인
count, ax = plt.subplots()

sns.countplot(data = tips, x = 'day', palette = 'viridis', legend = False, ax = ax)

ax.set_title('Count of days')
ax.set_xlabel('Day of the Week')
ax.set_ylabel('Frequency')

plt.show()
# Out:
# C:\Users\hpky0\AppData\Local\Temp\ipykernel_26580\1776742154.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data = tips, x = 'day', palette = 'viridis', legend = False, ax = ax)

# %% [markdown]
# ### `legend = False`를 작성했음에도 경고 문구가 떠 경고 문구를 다시 보니 '다음 버전에 그럴 것이다'를 미리 경고한 것임을 알게됨.
# ### 미리 경고한 것이지만 없앨 수 있는 지 궁금해 더 알아봄.
# ### 먼저 palette에 대해 알아보다 palette를 불러올 수 있음을 알게됨.
# ### 아래 코드를 작성해 palette를 적용시키고자 함.
# ```
# count, ax = plt.subplots()
#
# sns.set_palette('deep')
# sns.countplot(data = tips, x = 'day', ax = ax)
#
# ax.set_title('Count of days')
# ax.set_xlabel('Day of the Week')
# ax.set_ylabel('Frequency')
#
# plt.show()
# ```

# %%
# palette가 다른 색으로 적용이 되는 지 확인
count, ax = plt.subplots()

sns.set_palette('deep')
sns.countplot(data = tips, x = 'day', ax = ax)

ax.set_title('Count of days')
ax.set_xlabel('Day of the Week')
ax.set_ylabel('Frequency')

plt.show()

# %% [markdown]
# ### palette가 적용되지 않음
# ### palette를 불러오지 않아 적용되지 않은 것으로 생각돼 [아래 코드를 사용해 palette를 불러오기](https://seong6496.tistory.com/286)로 함.
# ```
# palette = sns.color_palette('Set3')
# sns.palplot(palette)
# ```

# %%
# palette가 불러와지는지 확인
palette = sns.color_palette('Set3')
sns.palplot(palette)

# %% [markdown]
# ### 아래 코드로 [불러온 palette를 적용](https://steadiness-193.tistory.com/297)해 경고 문구가 없어지는 지 확인하고자 함.
# ```
# count, ax = plt.subplots()
#
# sns.countplot(data = tips, x = 'day', palette = palette, ax = ax)
#
# ax.set_title('Count of days')
# ax.set_xlabel('Day of the Week')
# ax.set_ylabel('Frequency')
#
# plt.show()
# ```

# %%
# 불러온 palette 적용 시 경고 문구가 없어지는지 확인
count, ax = plt.subplots()

sns.countplot(data = tips, x = 'day', palette = palette, ax = ax)

ax.set_title('Count of days')
ax.set_xlabel('Day of the Week')
ax.set_ylabel('Frequency')

plt.show()
# Out:
# C:\Users\hpky0\AppData\Local\Temp\ipykernel_26580\1393715482.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data = tips, x = 'day', palette = palette, ax = ax)
# C:\Users\hpky0\AppData\Local\Temp\ipykernel_26580\1393715482.py:3: UserWarning: The palette list has more values (12) than needed (4), which may not be intended.
#   sns.countplot(data = tips, x = 'day', palette = palette, ax = ax)

# %% [markdown]
# ### palette의 색이 들어가기는 했지만 오히려 경고 문구는 늘어남.
# ### 추가된 경고 문구를 해석함.
# >팔레트 목록에 필요한 값(4)보다 더 많은 값(12)이 있는데 이는 의도하지 않은 것일 수 있습니다.
# ### 먼저 첫번째 경고 문구 먼저 해결하기로 함.
# ### palette 색을 지정했으니 다시 `legend = False`를 작성하면 없어지지 않을까싶어서 아래 코드를 사용해보고자 함.
# ```
# count, ax = plt.subplots()
#
# sns.countplot(data = tips, x = 'day', palette = palette, legend = False, ax = ax)
#
# ax.set_title('Count of days')
# ax.set_xlabel('Day of the Week')
# ax.set_ylabel('Frequency')
#
# plt.show()
# ```

# %%
# legend = False 작성해 경고 문구가 없어지는지 확인
count, ax = plt.subplots()

sns.countplot(data = tips, x = 'day', palette = palette, legend = False, ax = ax)

ax.set_title('Count of days')
ax.set_xlabel('Day of the Week')
ax.set_ylabel('Frequency')

plt.show()
# Out:
# C:\Users\hpky0\AppData\Local\Temp\ipykernel_26580\1530824019.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data = tips, x = 'day', palette = palette, legend = False, ax = ax)
# C:\Users\hpky0\AppData\Local\Temp\ipykernel_26580\1530824019.py:3: UserWarning: The palette list has more values (12) than needed (4), which may not be intended.
#   sns.countplot(data = tips, x = 'day', palette = palette, legend = False, ax = ax)

# %% [markdown]
# ### 경고 문구가 없어지지 않아 ['legend'가 무엇인지 알아보니 '범례'를 뜻](https://codetorial.net/matplotlib/set_legend.html)하는 것을 알게됨 .
# ### [legend = False가 범례 제거](https://www.delftstack.com/ko/howto/seaborn/remove-legend-seaborn-plot/)를 위해 사용되는 것을 알게됨.
# ### ['hue'를 사용하는 법](https://life-is-egg-study.tistory.com/7)을 알게됨.
# ### ['hue'가 '~에 따라 색을 다르게 하라는 의미'](https://wpaud16.tistory.com/entry/Seaborn-Scatterplot-%EA%B7%B8%EB%A6%AC%EA%B8%B0-ax-style-size-hue)임을 알게됨.
# ### hue를 지정하는 코드를 작성해 첫번째 경고 문구가 사라지는 지 확인하고자 함.
# ```
# count, ax = plt.subplots()
#
# sns.countplot(data = tips, x = 'day', palette = palette, hue = 'Day of the Week', legend = False, ax = ax)
#
# ax.set_title('Count of days')
# ax.set_xlabel('Day of the Week')
# ax.set_ylabel('Frequency')
#
# plt.show()
# ```

# %%
# hue를 지정해 경고 문구가 사라지는 지 확인
count, ax = plt.subplots()

sns.countplot(data = tips, x = 'day', palette = palette, hue = 'Day of the Week', legend = False, ax = ax)

ax.set_title('Count of days')
ax.set_xlabel('Day of the Week')
ax.set_ylabel('Frequency')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 3
#       1 count, ax = plt.subplots()
# ----> 3 sns.countplot(data = tips, x = 'day', palette = palette, hue = 'Day of the Week', legend = False, ax = ax)
#       5 ax.set_title('Count of days')
#       6 ax.set_xlabel('Day of the Week')
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2631, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, hue_norm, stat, width, dodge, gap, log_scale, native_scale, formatter, legend, ax, **kwargs)
#    2628 elif x is not None and y is not None:
#    2629     raise TypeError("Cannot pass values for both `x` and `y`.")
# -> 2631 p = _CategoricalAggPlotter(
#    2632     data=data,
#    2633     variables=dict(x=x, y=y, hue=hue),
#    2634     order=order,
#    2635     orient=orient,
#    2636     color=color,
# ...

# %% [markdown]
# ### 'hue'에 작성한 데이터 명이 없어 오류가 남.
# ### xlabel명을 작성해서 오류가 난 것으로 판단해 x값의 컬럼명을 작성해 경고 문구가 사라지는지 확인하고자 함.
# ```
# count, ax = plt.subplots()
#
# sns.countplot(data = tips, x = 'day', palette = palette, hue = 'day', legend = False, ax = ax)
#
# ax.set_title('Count of days')
# ax.set_xlabel('Day of the Week')
# ax.set_ylabel('Frequency')
#
# plt.show()
# ```

# %%
# x값의 컬럼명을 작성해 경고 문구가 사라지는지 확인
count, ax = plt.subplots()

sns.countplot(data = tips, x = 'day', palette = palette, hue = 'day', legend = False, ax = ax)

ax.set_title('Count of days')
ax.set_xlabel('Day of the Week')
ax.set_ylabel('Frequency')

plt.show()
# Out:
# C:\Users\hpky0\AppData\Local\Temp\ipykernel_26580\361443134.py:3: UserWarning: The palette list has more values (12) than needed (4), which may not be intended.
#   sns.countplot(data = tips, x = 'day', palette = palette, hue = 'day', legend = False, ax = ax)

# %% [markdown]
# ### 경고 문구가 사라짐. 첫 번째 경고 문구 없애기 해결 완료
# ### 두 번째 경고 문구를 해결하고자 함.
# ### 두 번째 경고 문구를 한 번 더 확인함.

# %%
# 경고 문구 재확인
count, ax = plt.subplots()

sns.countplot(data = tips, x = 'day', palette = palette, hue = 'day', legend = False, ax = ax)

ax.set_title('Count of days')
ax.set_xlabel('Day of the Week')
ax.set_ylabel('Frequency')

plt.show()
# Out:
# C:\Users\hpky0\AppData\Local\Temp\ipykernel_26580\3815358648.py:4: UserWarning: The palette list has more values (12) than needed (4), which may not be intended.
#   sns.countplot(data = tips, x = 'day', palette = palette, hue = 'day', legend = False, ax = ax)

# %% [markdown]
# ### 두번째 경고 문구는 불러온 palette의 값이 사용하는 것보다 많은 것이 문제가 된 것이므로 불러오는 palette의 개수를 지정할 수 있는 지 알아봄.
# ### 같은 문제가 있는 사람을 알게 되어 [해결 방법](https://stackoverflow.com/questions/77077529/how-can-i-resolve-userwarning-the-palette-list-has-more-values-10-than-neede)을 그대로 가져와 코드를 작성해 경고 문구가 사라지는지 확인하려함.
# ```
# palette = sns.color_palette('Set3', n_colors = 4)
# sns.palplot(palette)
# ```

# %%
# palette에 개수 지정해서 새로 palette 불러오기
palette = sns.color_palette('Set3', n_colors = 4)
sns.palplot(palette)

# %%
# 새로 불러온 palette 코드에 적용해 경고 문구 없어지는지 확인
count, ax = plt.subplots()

sns.countplot(data = tips, x = 'day', palette = palette, hue = 'day', legend = False, ax = ax)

ax.set_title('Count of days')
ax.set_xlabel('Day of the Week')
ax.set_ylabel('Frequency')

plt.show()

# %% [markdown]
# ## 경고 문구 없애기 해결 완료

# %% [markdown]
# ---

# %%
scatter, ax = plt.subplots()\

sns.scatterplot(data = tips, x = 'total_bill', y = 'tip', ax = ax)

ax.set_title('Scatter plot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')

plt.show()

# %%
reg, ax = plt.subplots()

sns.regplot(data = tips, x = 'total_bill', y = 'tip', ax = ax)

ax.set_title('Regression Plot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')

plt.show()

# %%
fig = sns.lmplot(data = tips, x = 'total_bill', y = 'tip')

plt.show()

# %%
joint = sns.jointplot(data = tips, x = 'total_bill', y = 'tip')
joint.set_axis_labels(xlabel = 'Total Bill', ylabel = 'Tips')

joint.figure.suptitle('Joint Plot of Total Bill and Tip', y = 1.03)

plt.show()

# %%
hexbin = sns.jointplot(data = tips, x = 'total_bill', y = 'tip', kind = 'hex')

hexbin.set_axis_labels(xlabel = 'Total Bill', ylabel = 'Tip')
hexbin.figure.suptitle('Hexbin Joint Plot of Total Bill and Tip', y = 1.03)

plt.show()

# %%
kde, ax = plt.subplots()

sns.kdeplot(data = tips, x = 'total_bill', y = 'tip', fill = True, ax = ax)

ax.set_title('Kernel Density Plot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')

plt.show()

# %%
kde2d = sns.jointplot(data = tips, x = 'total_bill', y = 'tip', kind = 'kde')

kde2d.set_axis_labels(xlabel = 'Total Bill', ylabel = 'Tip')
kde2d.figure.suptitle('Hexbin Joint Plot of Total Bill and Tip', y = 1.03)

plt.show()

# %%
import numpy as np

bar, ax = plt.subplots()

sns.barplot(data = tips, x = 'time', y = 'total_bill', estimator = np.mean, ax = ax)

ax.set_title('Bar Plot of Average Total Bill for Time of Day')
ax.set_xlabel('Time of Day')
ax.set_ylabel('Average Total Bill')

plt.show()

# %%
box, ax = plt.subplots()

sns.boxplot(data = tips, x = 'time', y = 'total_bill', ax = ax)

ax.set_title('Bar Plot of Total Bill for Time of Day')
ax.set_xlabel('Time of Day')
ax.set_ylabel('Total Bill')

plt.show()

# %%
# 매개변수 y 없이 박스 그래프 만들어보기
box, ax = plt.subplots()

sns.boxplot(data = tips, x = 'total_bill', ax = ax)

ax.set_title('Bar Plot of Total Bill for Time of Day')
ax.set_xlabel('Time of Day')
ax.set_ylabel('Total Bill')

plt.show()

# %%
violin, ax = plt.subplots()

sns.violinplot(data = tips, x = 'time', y = 'total_bill', ax = ax)

ax.set_title('Violin plot of total bill by time of day')
ax.set_xlabel('Time of day')
ax.set_ylabel('Total Bill')

plt.show()

# %%
box_violin, (ax1, ax2) = plt.subplots(nrows = 1, ncols = 2)

sns.boxplot(data = tips, x = 'time', y = 'total_bill', ax = ax1)
sns.violinplot(data = tips, x = 'time', y = 'total_bill', ax = ax2)

ax1.set_title('Box Plot')
ax1.set_xlabel('Time of Day')
ax1.set_ylabel('Total Bill')

ax2.set_title('Violin Plot')
ax2.set_xlabel('Time of Day')
ax2.set_ylabel('Total Bill')

box_violin.suptitle('Comparison of Box Plot with Violin Plot')

box_violin.set_tight_layout(True)

plt.show()

# %%
fig = sns.pairplot(data = tips)

fig.figure.suptitle('Pairwise Relationships of the Tips Data', y = 1.03)

plt.show()

# %%
pair_grid = sns.PairGrid(tips, diag_sharey = False)

pair_grid = pair_grid.map_upper(sns.regplot)
pair_grid = pair_grid.map_lower(sns.kdeplot)
pair_grid = pair_grid.map_diag(sns.histplot)

plt.show()

# %%
violin, ax = plt.subplots()

sns.violinplot(data = tips,
              x = 'time',
              y = 'total_bill',
              hue = 'smoker',
              split = True,
              palette = 'viridis',
              ax = ax)

plt.show()

# %%
violin, ax = plt.subplots()

sns.violinplot(data = tips,
              x = 'time',
              y = 'total_bill',
              hue = 'smoker',
              split = False,
              palette = 'viridis',
              ax = ax)

plt.show()

# %%
scatter = sns.lmplot(data = tips,
                    x = 'total_bill',
                    y = 'tip',
                    hue = 'smoker',
                    fit_reg = False,
                    palette = 'viridis')

plt.show()

# %%
fig = sns.pairplot(tips, hue = 'time', palette = 'viridis')
plt.show()

# %%
fig, ax = plt.subplots()

sns.scatterplot(data = tips,
               x = 'total_bill',
               y = 'tip',
               hue = 'time',
               size = 'size',
               palette = 'viridis',
               ax = ax)

plt.show()

# %%
anscombe = sns.load_dataset('anscombe')

# %%
anscombe_plot = sns.relplot(data = anscombe,
                           x = 'x',
                           y = 'y',
                           kind = 'scatter',
                           col = 'dataset',
                           col_wrap = 2,
                           height = 2,
                           aspect = 1.6)

anscombe_plot.figure.set_tight_layout(True)

plt.show()

# %%
colors = {
    'Yes' : '#f1a340',
    'No' : '#998ec3',
}

facet2 = sns.relplot(data = tips,
                    x = 'total_bill',
                    y = 'tip',
                    hue = 'smoker',
                    style = 'sex',
                    kind = 'scatter',
                    col = 'day',
                    row = 'time',
                    palette = colors,
                    height = 1.7)

facet2.set_titles(row_template = '{row_name}', col_template = '{col_name}')

sns.move_legend(facet2,
               loc = 'lower center',
               bbox_to_anchor = (0.5, 1),
               ncol = 2,
               title = None,
               frameon = False)

facet2.figure.set_tight_layout(True)

plt.show()

# %%
facet = sns.FacetGrid(tips, col = 'time')

facet.map(sns.histplot, 'total_bill')
plt.show()

# %%
facet = sns.FacetGrid(tips,
                     col = 'day',
                     col_wrap = 2,
                     hue = 'sex',
                     palette = 'viridis')

facet.map(plt.scatter, 'total_bill', 'tip')
facet.add_legend()
plt.show()

# %%
facet = sns.FacetGrid(tips,
                     col = 'time',
                     row = 'smoker',
                     hue = 'sex',
                     palette = 'viridis')

facet.map(plt.scatter, 'total_bill', 'tip')
plt.show()

# %%
facet = sns.catplot(x = 'day',
                   y = 'total_bill',
                   hue = 'sex',
                   data = tips,
                   row = 'smoker',
                   col = 'time',
                   kind = 'violin',
                   height = 3)

plt.show()

# %%
fig, ax = plt.subplots()
sns.violinplot(data = tips,
              x = 'time',
              y = 'total_bill',
              hue = 'sex',
              split = True,
              ax = ax)

plt.show()

# %%
with sns.axes_style('darkgrid'):
    fig, ax = plt.subplots()
    sns.violinplot(data = tips,
              x = 'time',
              y = 'total_bill',
              hue = 'sex',
              split = True,
              ax = ax)

plt.show()

# %%
seaborn_styles = ['darkgrid', 'whitegrid', 'dark', 'white', 'ticks']

fig = plt.figure()
for idx, style in enumerate(seaborn_styles):
    plot_position = idx + 1
    with sns.axes_style(style):
        ax = fig.add_subplot(2, 3, plot_position)
        violin = sns.violinplot(data = tips, x = 'time', y = 'total_bill', ax = ax)
        violin.set_title(style)
        
fig.set_tight_layout(True)
plt.show()

# %%
import pandas as pd

contexts = pd.DataFrame({
    'paper' : sns.plotting_context('paper'),
    'notebook' : sns.plotting_context('notebook'),
    'talk' : sns.plotting_context('talk'),
    'poster' : sns.plotting_context('poster'),
})
print(contexts)
# Out:
#                        paper  notebook    talk  poster
# axes.linewidth           1.0      1.25   1.875     2.5
# grid.linewidth           0.8      1.00   1.500     2.0
# lines.linewidth          1.2      1.50   2.250     3.0
# lines.markersize         4.8      6.00   9.000    12.0
# patch.linewidth          0.8      1.00   1.500     2.0
# xtick.major.width        1.0      1.25   1.875     2.5
# ytick.major.width        1.0      1.25   1.875     2.5
# xtick.minor.width        0.8      1.00   1.500     2.0
# ytick.minor.width        0.8      1.00   1.500     2.0
# xtick.major.size         4.8      6.00   9.000    12.0
# ytick.major.size         4.8      6.00   9.000    12.0
# xtick.minor.size         3.2      4.00   6.000     8.0
# ytick.minor.size         3.2      4.00   6.000     8.0
# font.size                9.6     12.00  18.000    24.0
# axes.labelsize           9.6     12.00  18.000    24.0
# axes.titlesize           9.6     12.00  18.000    24.0
# ...

# %%
context_styles = contexts.columns

fig = plt.figure()
for idx, context in enumerate(context_styles):
    plot_position = idx + 1
    with sns.plotting_context(context):
        ax = fig.add_subplot(2, 2, plot_position)
        violin = sns.violinplot(data = tips, x = 'time', y = 'total_bill', ax = ax)
        violin.set_title(context)
        
fig.set_tight_layout(True)
plt.show()

# %%
box_violin, (ax1, ax2) = plt.subplots(nrows = 1, ncols = 2)

sns.boxplot(data = tips, x = 'time', y = 'total_bill', ax = ax1)
sns.violinplot(data = tips, x = 'time', y = 'total_bill', ax = ax2)

ax1.set_title('Box Plot')
ax1.set_xlabel('Time of Day')
ax1.set_ylabel('Total Bill')

ax2.set_title('Violin plot')
ax2.set_xlabel('Time of Day')
ax2.set_ylabel('Total Bill')

box_violin.suptitle('Complarison of Box Plot with Violin Plot')

box_violin.set_tight_layout(True)
plt.show()

# %%
print(type(ax2))
# Out:
# <class 'matplotlib.axes._axes.Axes'>

# %%
print(type(box_violin))
# Out:
# <class 'matplotlib.figure.Figure'>

# %%
fig = sns.pairplot(data = tips)
fig.figure.suptitle('Pairwise Relationships of the Tips Data', y = 1.03)
plt.show()

# %%
print(type(fig))
# Out:
# <class 'seaborn.axisgrid.PairGrid'>

# %% [markdown]
# # 4 - 5

# %%
fig, ax = plt.subplots()
tips['total_bill'].plot.hist(ax = ax)
plt.show()

# %%
fig, ax = plt.subplots()
tips[['total_bill', 'tip']].plot.hist(alpha = 0.5, bins = 20, ax = ax)
plt.show()

# %%
fig, ax = plt.subplots()
tips['tip'].plot.kde(ax = ax)
plt.show()

# %%
fig, ax = plt.subplots()
tips.plot.scatter(x = 'total_bill', y = 'tip', ax = ax)
plt.show()

# %%
fig, ax = plt.subplots()
tips.plot.hexbin(x = 'total_bill', y = 'tip', ax = ax)
plt.show()

# %%
fig, ax = plt.subplots()
tips.plot.hexbin(x = 'total_bill', y = 'tip', gridsize = 10, ax = ax)
plt.show()

# %%
fig, ax = plt.subplots()
tips.plot.box(ax = ax)
plt.show()
